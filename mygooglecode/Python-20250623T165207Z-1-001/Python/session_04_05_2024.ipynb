# %%
print("Hello  World")
# Out:
# Hello  World

# %%
2**10
# Out:
# 1024

# %%
result = 2+5
result
# Out:
# 7

# %%
b =str("1234")
print(b)
# Out:
# 1234

# %%
a = input("enter radisu")
b=input("enter centr")

# %% [markdown]
# x=5
# y=10
# temp=x
# x=y
# y=temp
# print(x,y)

# %%
import string
letters=['a','e','i','o','u']

for i in string.ascii_uppercase:
  if i in "AEIOU":
    print(i, "Vowel")
  else:
    print(i,"Consonant")
# Out:
# A Vowel
# B Consonant
# C Consonant
# D Consonant
# E Vowel
# F Consonant
# G Consonant
# H Consonant
# I Vowel
# J Consonant
# K Consonant
# L Consonant
# M Consonant
# N Consonant
# O Vowel
# P Consonant
# Q Consonant
# R Consonant
# S Consonant
# T Consonant
# U Vowel
# V Consonant
# W Consonant
# X Consonant
# Y Consonant
# Z Consonant

# %%
a =int(input("Enter the number"))

print("Less thna 100") if(a<100)  else print("greater than 100")
# Out:
# Enter the number56
# Less thna 100

# %%
x=5

for i
